# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import warnings

warnings.filterwarnings("ignore")
# warnings.filterwarnings("default")

h = 0.01
n = 100
n = 1000
# n = 10000
# n = 100000

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

import warnings

# disable warnings temporarily
warnings.filterwarnings("ignore")
# warnings.filterwarnings("default")


# Define the exact solution
def exact_solution(x):
    return np.exp(x**2)

# Define the derivative function
def deriv_func(x, y):
    return 2*x*y

# Define the Forward Euler method
def forward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y = y + h*deriv_func(x, y)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Define the Backward Euler method
def backward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y_next = y + h*deriv_func(x, y)
        y = y + h*deriv_func(x+h, y_next)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Set the initial conditions and parameters
x0 = 0
y0 = 1
# h = 0.01
# n = 1000000

# Calculate the exact solution
x = np.linspace(x0, x0+h*n, n+1)
y_exact = exact_solution(x)

# Calculate the Forward Euler solution and time
y_forward, t_forward = forward_euler(deriv_func, x0, y0, h, n)

# Calculate the Backward Euler solution and time
y_backward, t_backward = backward_euler(deriv_func, x0, y0, h, n)

# Calculate the tolerance values
tol_forward = np.abs(y_forward - y_exact)
tol_backward = np.abs(y_backward - y_exact)

# Plot the results
plt.figure()
plt.plot(x, y_exact, label='Exact solution')
plt.plot(x, y_forward, label='Forward Euler')
plt.plot(x, y_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparison of ODE solutions')
plt.legend()

plt.figure()
plt.plot(x, tol_forward, label='Forward Euler')
plt.plot(x, tol_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('Tolerance')
plt.title('Tolerance of ODE solutions')
plt.legend()

print('Time taken by Forward Euler method:', t_forward)
print('Time taken by Backward Euler method:', t_backward)

APE_forward = np.mean(np.abs(tol_forward/y_exact))*100
APE_backward = np.mean(np.abs(tol_backward/y_exact))*100

# Print the results
print('Average percentage error of Forward Euler method:', APE_forward)
print('Average percentage error of Backward Euler method:', APE_backward)
# Out:
# Time taken by Forward Euler method: 0.0
# Time taken by Backward Euler method: 0.0
# Average percentage error of Forward Euler method: 52.97169368117692
# Average percentage error of Backward Euler method: 1849.9443534670977

# %%
# Define the exact solution
def exact_solution(x):
    return 0.5*(3*np.sin(x) - x*np.cos(x))

# Define the derivative function
def deriv_func(x, y):
    return np.array([y[1], np.sin(x) - y[0]])

# Define the Forward Euler method
def forward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y[0]]
    for i in range(n):
        y = y + h*deriv_func(x, y)
        x = x + h
        y_list.append(y[0])
    t1 = time.time()
    return np.array(y_list), t1-t0

# Define the Backward Euler method
def backward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y[0]]
    for i in range(n):
        y_next = y + h*deriv_func(x, y)
        y = y + h*deriv_func(x+h, y_next)
        x = x + h
        y_list.append(y[0])
    t1 = time.time()
    return np.array(y_list), t1-t0

# Set the initial conditions and parameters
x0 = 0
y0 = np.array([0, 1])
# h = 0.1
# n = 10000

# Calculate the exact solution
x = np.linspace(x0, x0+h*n, n+1)
y_exact = exact_solution(x)

# Calculate the Forward Euler solution and time
y_forward, t_forward = forward_euler(deriv_func, x0, y0, h, n)

# Calculate the Backward Euler solution and time
y_backward, t_backward = backward_euler(deriv_func, x0, y0, h, n)

# Calculate the tolerance values
tol_forward = np.abs(y_forward - y_exact)
tol_backward = np.abs(y_backward - y_exact)

# Plot the results
plt.figure()
plt.plot(x, y_exact, label='Exact solution')
plt.plot(x, y_forward, label='Forward Euler')
plt.plot(x, y_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparison of ODE solutions')
plt.legend()

plt.figure()
plt.plot(x, tol_forward, label='Forward Euler')
plt.plot(x, tol_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('Tolerance')
plt.title('Tolerance of ODE solutions')
plt.legend()

print('Time taken by Forward Euler method:', t_forward)
print('Time taken by Backward Euler method:', t_backward)

APE_forward = np.mean(np.abs(tol_forward/y_exact))*100
APE_backward = np.mean(np.abs(tol_backward/y_exact))*100

# Print the results
print('Average percentage error of Forward Euler method:', APE_forward)
print('Average percentage error of Backward Euler method:', APE_backward)
# Out:
# Time taken by Forward Euler method: 0.00400543212890625
# Time taken by Backward Euler method: 0.005512714385986328
# Average percentage error of Forward Euler method: nan
# Average percentage error of Backward Euler method: nan

# %%
# Define the exact solution
def exact_solution(x):
    return 2*x + 2*np.exp(-x) + 2*np.cos(x) - 3

# Define the derivative function in terms of y'
def deriv_func(x, y):
    return np.array([y[1], y[2], y[3], 2*x - 1 - y[2] - y[1] - y[0]])

# Define the Forward Euler method
def forward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y = y + h*deriv_func(x, y)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Define the Backward Euler method
def backward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y_next = y + h*deriv_func(x, y)
        y = y + h*deriv_func(x+h, y_next)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Set the initial conditions and parameters
x0 = 0
y0 = np.array([1, 0, 0, 0])
# h = 0.1
# n = 100000

# Calculate the exact solution
x = np.linspace(x0, x0+h*n, n+1)
y_exact = exact_solution(x)

# Calculate the Forward Euler solution and time
y_forward, t_forward = forward_euler(deriv_func, x0, y0, h, n)

# Calculate the Backward Euler solution and time
y_backward, t_backward = backward_euler(deriv_func, x0, y0, h, n)

# Calculate the tolerance values
tol_forward = np.abs(y_forward[:,0] - y_exact)
tol_backward = np.abs(y_backward[:,0] - y_exact)

# Plot the results
plt.figure()
plt.plot(x, y_exact, label='Exact solution', linewidth=2)
plt.plot(x, y_forward[:,0], label='Forward Euler')
plt.plot(x, y_backward[:,0], label='Backward Euler')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparison of ODE solutions')
plt.legend()

plt.figure()
plt.plot(x, tol_forward, label='Forward Euler')
plt.plot(x, tol_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('Tolerance')
plt.title('Tolerance of ODE solutions')
plt.legend()

print('Time taken by Forward Euler method:', t_forward)
print('Time taken by Backward Euler method:', t_backward)

APE_forward = np.mean(np.abs(tol_forward/y_exact))*100
APE_backward = np.mean(np.abs(tol_backward/y_exact))*100

# Print the results
print('Average percentage error of Forward Euler method:', APE_forward)
print('Average percentage error of Backward Euler method:', APE_backward)
# Out:
# Time taken by Forward Euler method: 0.0030012130737304688
# Time taken by Backward Euler method: 0.006511211395263672
# Average percentage error of Forward Euler method: 132.9006036817239
# Average percentage error of Backward Euler method: 118.1563611655337

# %%
# Define the exact solution
def exact_solution(x):
    return ((x-1)*np.sin(np.sqrt(2)*x))/np.sqrt(2) + (x+1)*np.cos(np.sqrt(2)*x)

# Define the derivative function
def deriv_func(x, y):
    return np.array([y[1], y[2], y[3], -4*y[2] - 4*y[0]])

# Define the Forward Euler method
def forward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y = y + h*deriv_func(x, y)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Define the Backward Euler method
def backward_euler(deriv_func, x0, y0, h, n):
    t0 = time.time()
    x = x0
    y = y0
    y_list = [y0]
    for i in range(n):
        y_next = y + h*deriv_func(x, y)
        y = y + h*deriv_func(x+h, y_next)
        x = x + h
        y_list.append(y)
    t1 = time.time()
    return np.array(y_list), t1-t0

# Set the initial conditions and parameters
x0 = 0
y0 = np.array([1, 0, 0, -4])
# h = 0.05
# n = 100000

# Calculate the exact solution
x = np.linspace(x0, x0+h*n, n+1)
y_exact = exact_solution(x)

# Calculate the Forward Euler solution and time
y_forward, t_forward = forward_euler(deriv_func, x0, y0, h, n)

# Calculate the Backward Euler solution and time
y_backward, t_backward = backward_euler(deriv_func, x0, y0, h, n)

# Calculate the tolerance values
tol_forward = np.abs(y_forward[:,0] - y_exact)
tol_backward = np.abs(y_backward[:,0] - y_exact)

# Plot the results
plt.figure()
plt.plot(x, y_exact, label='Exact solution', linewidth=2)
plt.plot(x, y_forward[:,0], label='Forward Euler')
plt.plot(x, y_backward[:,0], label='Backward Euler')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparison of ODE solutions')
plt.legend()

plt.figure()
plt.plot(x, tol_forward, label='Forward Euler')
plt.plot(x, tol_backward, label='Backward Euler')
plt.xlabel('x')
plt.ylabel('Tolerance')
plt.title('Tolerance of ODE solutions')
plt.legend()

print('Time taken by Forward Euler method:', t_forward)
print('Time taken by Backward Euler method:', t_backward)


# Calculate the relative error (as a percentage) and average over the domain
# average percentage error (APE) APE = 1/n * ∑(|(y_numerical - y_exact)/y_exact|) * 100%
APE_forward = np.mean(np.abs(tol_forward/y_exact))*100
APE_backward = np.mean(np.abs(tol_backward/y_exact))*100

# Print the results
print('Average percentage error of Forward Euler method:', APE_forward)
print('Average percentage error of Backward Euler method:', APE_backward)
# Out:
# Time taken by Forward Euler method: 0.004515171051025391
# Time taken by Backward Euler method: 0.006999015808105469
# Average percentage error of Forward Euler method: 9.16491633520856
# Average percentage error of Backward Euler method: 8.556671101650801
